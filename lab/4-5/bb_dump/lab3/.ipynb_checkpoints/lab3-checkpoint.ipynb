# %% [markdown]
# # Dependencies and initial setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


# all the functions are in lib/
from lib.test import *
from lib.tcp import *

def setup_dependencies():
    # This callback is needed to execute commands from the outside file in lib/
    def exec_cmd(cmd):
        out = !{cmd}
        return out

    set_exec_callback(exec_cmd)
    set_tcp_exec_callback(exec_cmd)
    setup_kernel()
    
setup_dependencies()
setup_pipes()
# !sysctl kern.ipc.maxsockbuf=33554432
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# kern.ipc.maxsockbuf: 33554432 -> 33554432

# %%
# !pwd
# Out:
# /data/lab3

# %%
# !ls
# Out:
# .ipynb_checkpoints  lab3.ipynb          lib
# ipc                 lab4_template.ipynb

# %% [markdown]
# # Example commands

# %%
latency = 10

# !ipfw pipe config 1 delay {str(latency)}
# !ipfw pipe config 2 delay {str(latency)}

# %%
print_header("Creating file to run benchmark")

# !ipc/ipc-static -v -i tcp 2thread
    
print_footer("Completed")
# Out:
# ********************************************************************************
# * Creating file to run benchmark
# ********************************************************************************
# ^C
# ********************************************************************************
# * Completed
# ********************************************************************************

# %% [markdown]
# ## Structures

# %% [markdown]
# ```c
# struct tcphdr {
#     u_short th_sport = 0x9d27
#     u_short th_dport = 0x1896
#     tcp_seq th_seq = 0x6e0e1290
#     tcp_seq th_ack = 0xa79a5193
#     unsigned char th_x2 :4 = 0
#     unsigned char th_off :4 = 0xa
#     u_char th_flags = 0x12
#     u_short th_win = 0xffff
#     u_short th_sum = 0
#     u_short th_urp = 0
# }
#
# struct tcpcb {
#     struct tsegqe_head t_segq = {
#         struct tseg_qent *lh_first = 0
#     }
#     void *[2] t_pspare = [ 0, 0 ]
#     int t_segqlen = 0
#     int t_dupacks = 0
#     struct tcp_timer *t_timers = 0xc3ce0200
#     struct inpcb *t_inpcb = 0xc3cb3af8
#     int t_state = 0x2
#     u_int t_flags = 0x2a0
#     struct vnet *t_vnet = 0
#     tcp_seq snd_una = 0xa79a5192
#     tcp_seq snd_max = 0xa79a5193
#     tcp_seq snd_nxt = 0xa79a5193
#     tcp_seq snd_up = 0xa79a5192
#     tcp_seq snd_wl1 = 0
#     tcp_seq snd_wl2 = 0
#     tcp_seq iss = 0xa79a5192
#     tcp_seq irs = 0
#     tcp_seq rcv_nxt = 0
#     tcp_seq rcv_adv = 0xffff
#     u_long rcv_wnd = 0
#     tcp_seq rcv_up = 0
#     u_long snd_wnd = 0
#     u_long snd_cwnd = 0x3fffc000
#     u_long snd_spare1 = 0
#     u_long snd_ssthresh = 0x3fffc000
#     u_long snd_spare2 = 0
#     tcp_seq snd_recover = 0xa79a5192
#     u_int t_rcvtime = 0x80065647
#     u_int t_starttime = 0
#     u_int t_rtttime = 0x80065647
#     tcp_seq t_rtseq = 0xa79a5192
#     u_int t_bw_spare1 = 0
#     tcp_seq t_bw_spare2 = 0
#     int t_rxtcur = 0x12c
#     u_int t_maxseg = 0x218
#     u_int t_pmtud_saved_maxseg = 0
#     int t_srtt = 0
#     int t_rttvar = 0x4b0
#     int t_rxtshift = 0
#     u_int t_rttmin = 0x3
#     u_int t_rttbest = 0
#     u_long t_rttupdated = 0
#     u_long max_sndwnd = 0
#     int t_softerror = 0
#     char t_oobflags = '\0'
#     char t_iobc = '\0'
#     u_char snd_scale = 0
#     u_char rcv_scale = 0
#     u_char request_r_scale = 0xa
#     u_int32_t ts_recent = 0
#     u_int ts_recent_age = 0
#     u_int32_t ts_offset = 0
#     tcp_seq last_ack_sent = 0
#     u_long snd_cwnd_prev = 0
#     u_long snd_ssthresh_prev = 0
#     tcp_seq snd_recover_prev = 0
#     int t_sndzerowin = 0
#     u_int t_badrxtwin = 0
#     u_char snd_limited = 0
#     int snd_numholes = 0
#     tcp_seq snd_fack = 0
#     int rcv_numsacks = 0
#
# }
# ```

# %%
from IPython.display import display
setup_dependencies()
display(graph_tcp(10))
display(graph_tcp(40))
# Out:
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed

# %%
from IPython.display import display
setup_dependencies()
for i in range(0,41,5):
    display(graph_tcp(i))
# Out:
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed

# %%
setup_dependencies()
display(graph_tcp(40))
# Out:
# Running ipc benchmark
# Completed

# %%
benchmark_tcp_bandwith(latencies=range(0,41,5), trials= 10, output_name="latencies.json")
# Out:
# Latency: 0
# Latency: 5
# Latency: 10
# Latency: 15
# Latency: 20
# Latency: 25
# Latency: 30
# Latency: 35
# Latency: 40
# values collected: 90
# {'latencies': [0, 5, 10, 15, 20, 25, 30, 35, 40],
#  'output': ['625284782',
#   '711630068',
#   '616284068',
#   '708806887',
#   '628682544',
#   '614215587',
#   '618293932',
#   '620681917',
#   '617764533',
#   '617009439',
#   '702156262',
#   '616898966',
#   '616141465',
#   '615782372',
#   '615275557',
#   '616973904',
#   '618796072',
#   '616312152',
#   '708060105',
#   '709587804',
#   '3519425493',
#   '3519237859',
#   '3519416508',
#   '3519434785',
#   '3519418278',
#   '3519412789',
#   '3418946239',
#   '3460355938',
#   '3519406285',
#   '3519446378',
#   '3519449878',
#   '3519399136',
#   '3519411378',
#   '3519448028',
#   '3519417515',
#   '3519401951',
#   '3519430751',
#   '3519404285',
#   '3519408091',
#   '3519405495',
#   '6936509850',
#   '6939390553',
#   '6939407509',
#   '6939388914',
#   '6939197853',
#   '6939468554',
#   '6939347249',
#   '6939356713',
#   '6939394799',
#   '6939329820',
#   '6939384788',
#   '6939369562',
#   '6939384011',
#   '6939310564',
#   '6939450916',
#   '6939449744',
#   '6939424365',
#   '6939424662',
#   '6939390537',
#   '6939366214',
#   '31259366988',
#   '31259331787',
#   '31259254726',
#   '31259324016',
#   '31259291540',
#   '31259291715',
#   '31259346410',
#   '31259343145',
#   '31259394606',
#   '31259306061',
#   '31259307144',
#   '31259269746',
#   '31259341918',
#   '31259323415',
#   '31259306748',
#   '31259323804',
#   '31259341624',
#   '31259338755',
#   '31259325953',
#   '31259307315',
#   '41679136925',
#   '41679219431',
#   '41679383949',
#   '41679386239',
#   '41679218687',
#   '41679360528',
#   '41679372056',
#   '41679255792',
#   '41679277477',
#   '41678837933'],
#  'program_outputs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']}

# %%
benchmark_tcp_bandwith(latencies=range(0,41,5), flags= "-s",trials=10, output_name="latencies_s.json")
# Out:
# Latency: 0
# Latency: 5
# Latency: 10
# Latency: 15
# Latency: 20
# Latency: 25
# Latency: 30
# Latency: 35
# Latency: 40
# values collected: 90
# {'latencies': [0, 5, 10, 15, 20, 25, 30, 35, 40],
#  'output': ['704202068',
#   '695987306',
#   '695426544',
#   '697006988',
#   '699486381',
#   '690085045',
#   '694042829',
#   '702035810',
#   '700390866',
#   '699329412',
#   '694932596',
#   '699189349',
#   '689592922',
#   '700474325',
#   '698821151',
#   '691714109',
#   '691169787',
#   '701263657',
#   '707832898',
#   '694021471',
#   '3189297533',
#   '3189432333',
#   '3189446873',
#   '3189437137',
#   '3189433380',
#   '3189401741',
#   '3189124437',
#   '3189444045',
#   '3189394082',
#   '3189441015',
#   '3189443520',
#   '3189447778',
#   '3189445706',
#   '3189448856',
#   '3189429213',
#   '3189399557',
#   '3189452383',
#   '3188036164',
#   '3189451771',
#   '3189429539',
#   '6169412679',
#   '6169379128',
#   '6169410882',
#   '6169388184',
#   '6169416496',
#   '6169341609',
#   '6169391686',
#   '6169366216',
#   '6169421145',
#   '6169410505',
#   '6169212872',
#   '6169414558',
#   '6169384691',
#   '6169355290',
#   '6169439483',
#   '6169406547',
#   '6169428962',
#   '6169460463',
#   '6169300155',
#   '6169461624',
#   '7749408978',
#   '7949412157',
#   '7629470440',
#   '7509375171',
#   '7389408246',
#   '7269301999',
#   '7149386570',
#   '6909415153',
#   '6889334614',
#   '6669433108',
#   '7749376043',
#   '7949377130',
#   '7629436460',
#   '7509331428',
#   '7389408317',
#   '7269327831',
#   '7149357736',
#   '6909390309',
#   '6890401677',
#   '6669405943',
#   '10329377025',
#   '10529297575',
#   '10169401536',
#   '10009499558',
#   '9849392229',
#   '9689371565',
#   '9529385954',
#   '9209533938',
#   '9149323618',
#   '8889421686'],
#  'program_outputs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']}

# %%
ax = plot_tcp_bandwidth(input_data_file="latencies.json",trials=10,y_label="Bandwith (KB/s)",x_label="Latency (ms)",label="tcp")
plot_tcp_bandwidth(input_data_file="latencies_s.json",trials=10,label="tcp -s (without autoresizing)", title="TCP bandwidth vs Latency", axis = ax, save_name="tcp_bandwidth.png")
# Out:
# xvs len: 9 yvs len: 27 trials: 3
# xvs len: 9 yvs len: 27 trials: 3

# %%
att_latency = 5
JSON_ALL_VARIABLES = "all_variables_{}.json".format(att_latency)
JSON_ALL_VARIABLES_S = "all_variables_{}_s.json".format(att_latency)

# %%
benchmark_variables(latency=att_latency,flags="-s",output_name=JSON_ALL_VARIABLES_S)
# Out:
# Latency: 5
# values collected: 140456
# {'latencies': [5],
#  'output': ['snd_cwnd:1073725440',
#   'th_seq:3808016924',
#   'snd_wnd:0',
#   'th_dport:65424',
#   'timestamp:801200813',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:1073725440',
#   'th_seq:3648092848',
#   'snd_wnd:0',
#   'th_dport:10141',
#   'timestamp:801364096',
#   'th_sport:65424',
#   'th_ack:3808016925',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808016925',
#   'snd_wnd:65535',
#   'th_dport:65424',
#   'timestamp:801462345',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14481',
#   'th_seq:3648092848',
#   'snd_wnd:65536',
#   'th_dport:10141',
#   'timestamp:801585295',
#   'th_sport:65424',
#   'th_ack:3808018373',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808018373',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801666042',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808019821',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801693723',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808021269',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801724183',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808022717',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801737747',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808024165',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801761792',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808025613',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801774554',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808027061',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801797783',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808028509',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801810607',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808029957',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801832794',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808031405',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:801845060',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:15929',
#   'th_seq:3648092848',
#   'snd_wnd:1048576',
#   'th_dport:10141',
#   'timestamp:801867694',
#   'th_sport:65424',
#   'th_ack:3808021269',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:18825',
#   'th_seq:3648092848',
#   'snd_wnd:1045504',
#   'th_dport:10141',
#   'timestamp:801925693',
#   'th_sport:65424',
#   'th_ack:3808024165',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:21721',
#   'th_seq:3648092848',
#   'snd_wnd:1042432',
#   'th_dport:10141',
#   'timestamp:801980554',
#   'th_sport:65424',
#   'th_ack:3808027061',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:24617',
#   'th_seq:3648092848',
#   'snd_wnd:1039360',
#   'th_dport:10141',
#   'timestamp:802036755',
#   'th_sport:65424',
#   'th_ack:3808029957',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:27513',
#   'th_seq:3648092848',
#   'snd_wnd:1036288',
#   'th_dport:10141',
#   'timestamp:802091883',
#   'th_sport:65424',
#   'th_ack:3808032853',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808032853',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802147390',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808034301',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802163042',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808035749',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802185890',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808037197',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802198215',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808038645',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802221088',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808040093',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802233349',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808041541',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802255600',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808042989',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802267940',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808044437',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802290464',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808045885',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802303022',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808047333',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802326272',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808048781',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802338958',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808050229',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802362395',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808051677',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802374708',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808053125',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802397013',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808054573',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802409356',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808056021',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802431812',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808057469',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802444283',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808058917',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802467009',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808060365',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:802479620',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:30409',
#   'th_seq:3648092848',
#   'snd_wnd:1033216',
#   'th_dport:10141',
#   'timestamp:802502184',
#   'th_sport:65424',
#   'th_ack:3808035749',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:33305',
#   'th_seq:3648092848',
#   'snd_wnd:1031168',
#   'th_dport:10141',
#   'timestamp:802555097',
#   'th_sport:65424',
#   'th_ack:3808038645',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:36201',
#   'th_seq:3648092848',
#   'snd_wnd:1028096',
#   'th_dport:10141',
#   'timestamp:802608702',
#   'th_sport:65424',
#   'th_ack:3808041541',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:39097',
#   'th_seq:3648092848',
#   'snd_wnd:1025024',
#   'th_dport:10141',
#   'timestamp:802664556',
#   'th_sport:65424',
#   'th_ack:3808044437',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:41993',
#   'th_seq:3648092848',
#   'snd_wnd:1021952',
#   'th_dport:10141',
#   'timestamp:802718942',
#   'th_sport:65424',
#   'th_ack:3808047333',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:44889',
#   'th_seq:3648092848',
#   'snd_wnd:1018880',
#   'th_dport:10141',
#   'timestamp:802774380',
#   'th_sport:65424',
#   'th_ack:3808050229',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:47785',
#   'th_seq:3648092848',
#   'snd_wnd:1015808',
#   'th_dport:10141',
#   'timestamp:802830410',
#   'th_sport:65424',
#   'th_ack:3808053125',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:50681',
#   'th_seq:3648092848',
#   'snd_wnd:1013760',
#   'th_dport:10141',
#   'timestamp:802885147',
#   'th_sport:65424',
#   'th_ack:3808056021',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:53577',
#   'th_seq:3648092848',
#   'snd_wnd:1010688',
#   'th_dport:10141',
#   'timestamp:802941428',
#   'th_sport:65424',
#   'th_ack:3808058917',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:56473',
#   'th_seq:3648092848',
#   'snd_wnd:1007616',
#   'th_dport:10141',
#   'timestamp:802997683',
#   'th_sport:65424',
#   'th_ack:3808061813',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808061813',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803054042',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808063261',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803069512',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808064709',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803093674',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808066157',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803106516',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808067605',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803128487',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808069053',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803140851',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808070501',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803163457',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808071949',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803175925',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808073397',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803198451',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808074845',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803211572',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808076293',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803233840',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808077741',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803246780',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808079189',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803269069',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808080637',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803281384',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808082085',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803303785',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808083533',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803316796',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808084981',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803339155',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808086429',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803351440',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808087877',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803373295',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808089325',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803386929',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808090773',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803409555',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808092221',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803422005',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808093669',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803444635',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808095117',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803457495',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808096565',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803479747',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808098013',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803492503',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808099461',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803515229',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808100909',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803527849',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808102357',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803550592',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808103805',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803563493',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808105253',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803585689',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808106701',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803598014',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808108149',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803620702',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808109597',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803633164',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808111045',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803655212',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808112493',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803667849',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808113941',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803690192',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808115389',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803702953',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808116837',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803725288',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808118285',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:803737858',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:59369',
#   'th_seq:3648092848',
#   'snd_wnd:1004544',
#   'th_dport:10141',
#   'timestamp:803761583',
#   'th_sport:65424',
#   'th_ack:3808064709',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:62265',
#   'th_seq:3648092848',
#   'snd_wnd:1001472',
#   'th_dport:10141',
#   'timestamp:803815876',
#   'th_sport:65424',
#   'th_ack:3808067605',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:65161',
#   'th_seq:3648092848',
#   'snd_wnd:998400',
#   'th_dport:10141',
#   'timestamp:803867688',
#   'th_sport:65424',
#   'th_ack:3808070501',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:68057',
#   'th_seq:3648092848',
#   'snd_wnd:996352',
#   'th_dport:10141',
#   'timestamp:803922336',
#   'th_sport:65424',
#   'th_ack:3808073397',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:70953',
#   'th_seq:3648092848',
#   'snd_wnd:993280',
#   'th_dport:10141',
#   'timestamp:803975401',
#   'th_sport:65424',
#   'th_ack:3808076293',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:73849',
#   'th_seq:3648092848',
#   'snd_wnd:990208',
#   'th_dport:10141',
#   'timestamp:804030129',
#   'th_sport:65424',
#   'th_ack:3808079189',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:76745',
#   'th_seq:3648092848',
#   'snd_wnd:987136',
#   'th_dport:10141',
#   'timestamp:804085023',
#   'th_sport:65424',
#   'th_ack:3808082085',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:79641',
#   'th_seq:3648092848',
#   'snd_wnd:984064',
#   'th_dport:10141',
#   'timestamp:804139034',
#   'th_sport:65424',
#   'th_ack:3808084981',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:82537',
#   'th_seq:3648092848',
#   'snd_wnd:980992',
#   'th_dport:10141',
#   'timestamp:804195098',
#   'th_sport:65424',
#   'th_ack:3808087877',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:85433',
#   'th_seq:3648092848',
#   'snd_wnd:978944',
#   'th_dport:10141',
#   'timestamp:804249944',
#   'th_sport:65424',
#   'th_ack:3808090773',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:88329',
#   'th_seq:3648092848',
#   'snd_wnd:975872',
#   'th_dport:10141',
#   'timestamp:804340759',
#   'th_sport:65424',
#   'th_ack:3808093669',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:91225',
#   'th_seq:3648092848',
#   'snd_wnd:972800',
#   'th_dport:10141',
#   'timestamp:804400187',
#   'th_sport:65424',
#   'th_ack:3808096565',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:94121',
#   'th_seq:3648092848',
#   'snd_wnd:969728',
#   'th_dport:10141',
#   'timestamp:804458928',
#   'th_sport:65424',
#   'th_ack:3808099461',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:97017',
#   'th_seq:3648092848',
#   'snd_wnd:966656',
#   'th_dport:10141',
#   'timestamp:804514667',
#   'th_sport:65424',
#   'th_ack:3808102357',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:99913',
#   'th_seq:3648092848',
#   'snd_wnd:963584',
#   'th_dport:10141',
#   'timestamp:804569942',
#   'th_sport:65424',
#   'th_ack:3808105253',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:102809',
#   'th_seq:3648092848',
#   'snd_wnd:961536',
#   'th_dport:10141',
#   'timestamp:804625919',
#   'th_sport:65424',
#   'th_ack:3808108149',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:105705',
#   'th_seq:3648092848',
#   'snd_wnd:958464',
#   'th_dport:10141',
#   'timestamp:804691958',
#   'th_sport:65424',
#   'th_ack:3808111045',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:108601',
#   'th_seq:3648092848',
#   'snd_wnd:955392',
#   'th_dport:10141',
#   'timestamp:804749421',
#   'th_sport:65424',
#   'th_ack:3808113941',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:111497',
#   'th_seq:3648092848',
#   'snd_wnd:952320',
#   'th_dport:10141',
#   'timestamp:804806199',
#   'th_sport:65424',
#   'th_ack:3808116837',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:114393',
#   'th_seq:3648092848',
#   'snd_wnd:949248',
#   'th_dport:10141',
#   'timestamp:804862513',
#   'th_sport:65424',
#   'th_ack:3808119733',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808119733',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:804920072',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808121181',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:804936728',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808122629',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:804963482',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808124077',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:804976509',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808125525',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805000075',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808126973',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805013748',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808128421',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805037022',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808129869',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805050528',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808131317',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805073260',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808132765',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805086343',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808134213',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805109381',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808135661',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805121988',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808137109',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805144781',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808138557',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805157766',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808140005',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805180616',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3808141453',
#   'snd_wnd:65536',
#   'th_dport:65424',
#   'timestamp:805193612',
#   'th_sport:10141',
#   'th_ack:3648092848',
#   'snd_ssthresh:1073725440',
#   ...],
#  'program_outputs': ['']}

# %%
setup_dependencies()
benchmark_variables(latency=att_latency,output_name=JSON_ALL_VARIABLES)
benchmark_variables(latency=att_latency,flags="-s",output_name=JSON_ALL_VARIABLES_S)
plot_variable(JSON_ALL_VARIABLES, "th_seq", sender_side = False)
plot_variable(JSON_ALL_VARIABLES_S, "th_seq", sender_side = False)
# Out:
# Latency: 5
# values collected: 140120
# Latency: 5
# values collected: 140440
# Data prepared. Now plotting th_seq..
# xvs len: 11663 yvs len: 11663 trials: 1
# Data prepared. Now plotting th_seq..
# xvs len: 11663 yvs len: 11663 trials: 1

# %%
ax = plot_tcp_bandwidth_across_time(JSON_ALL_VARIABLES, 
                                    label="tcp", 
                                    sender_side=False)
plot_tcp_bandwidth_across_time(JSON_ALL_VARIABLES_S,
                               title="TCP bandwith across time with {}ms latency".format(att_latency),
                               axis = ax, 
                               label="tcp -s", 
                               sender_side=False)
ax.set_yscale(log)
# factor = 20, times = 10, time diff 0.0001
# factor = 20 times =
# Out:
# Data prepared. Now plotting..
# xvs len: 1017 yvs len: 1017 trials: 1
# Data prepared. Now plotting..
# xvs len: 1015 yvs len: 1015 trials: 1

# %%
ax = plot_tcp_bandwidth_across_time(JSON_ALL_VARIABLES, sender_side=False)
# factor 100, times 3, time diff 0.0001
# Out:
# Data prepared. Now plotting..
# xvs len: 1053 yvs len: 1053 trials: 1

# %%
ax = plot_variable(JSON_ALL_VARIABLES, "snd_cwnd", sender_side = True)
#ax = plot_variable(JSON_ALL_VARIABLES, "snd_cwnd", sender_side = False)
#ax.set_xlim(0,0.1)
# Out:
# Data prepared. Now plotting snd_cwnd..
# xvs len: 5876 yvs len: 5876 trials: 1

# %%
plot_tcp_cwnd_wnd_ssthresh(JSON_ALL_VARIABLES, title="TCP variables")
plot_tcp_cwnd_wnd_ssthresh(JSON_ALL_VARIABLES_S, title="TCP variables -s")
# Out:
# Data prepared. Now plotting snd_cwnd..
# xvs len: 5892 yvs len: 5892 trials: 1
# Data prepared. Now plotting snd_wnd..
# xvs len: 5892 yvs len: 5892 trials: 1
# Data prepared. Now plotting snd_ssthresh..
# xvs len: 5892 yvs len: 5892 trials: 1
# Data prepared. Now plotting snd_cwnd..
# xvs len: 5892 yvs len: 5892 trials: 1
# Data prepared. Now plotting snd_wnd..
# xvs len: 5892 yvs len: 5892 trials: 1
# Data prepared. Now plotting snd_ssthresh..
# xvs len: 5892 yvs len: 5892 trials: 1

# %%
plot_min_window(JSON_ALL_VARIABLES)
# Out:
# ('lengths: ', 0, 0)
# ('yvs len: ', 0, 'timelen: ', 0)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-848f5a5067db> in <module>()
# ----> 1 plot_min_window(JSON_ALL_VARIABLES)
#
# /data/lab3/lib/tcp.py in plot_min_window(input, title, save_name)
#     535     ax = None
#     536     ax = plot_variable(input, "Minimum window", title=title, sender_side=True,
# --> 537                        alpha=1, linewidth=4, ax=ax)
#     538     ax = plot_variable(input, "snd_cwnd", ax=ax, sender_side=True,
#     539                        filter_maximum=True)
#
# /data/lab3/lib/tcp.py in plot_variable(input_name, var, title, ax, sender_side, filter_maximum, min_window, linewidth, alpha)
#     504     if filter_maximum:
#     505         yvs = [i if i < 1e6 else 0 for i in yvs]
# --> 506     offset = time[0]
#     507     time = [i - offset for i in time]
#     508     max_time = time[-1] / 1e9
#
# IndexError: list index out of range

# %%
# !ipc/ipc-static -i tcp -B -b 1048576 -q 2thread
