# %% [markdown]
# # Dependencies and initial setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


# all the functions are in lib/
from lib.test import *
from lib.tcp import *

def setup_dependencies():
    # This callback is needed to execute commands from the outside file in lib/
    def exec_cmd(cmd):
        out = !{cmd}
        return out

    set_exec_callback(exec_cmd)
    set_tcp_exec_callback(exec_cmd)
    setup_kernel()
    
setup_dependencies()
setup_pipes()
# !sysctl kern.ipc.maxsockbuf=33554432
# Out:
# kern.ipc.maxsockbuf: 33554432 -> 33554432

# %%
# !pwd
# Out:
# /data/lab3

# %%
# !ls
# Out:
# .ipynb_checkpoints  lab3.ipynb          lib
# ipc                 lab4_template.ipynb

# %% [markdown]
# # Example commands

# %%
latency = 10

# !ipfw pipe config 1 delay {str(latency)}
# !ipfw pipe config 2 delay {str(latency)}

# %%
print_header("Creating file to run benchmark")

# !ipc/ipc-static -v -i tcp 2thread
    
print_footer("Completed")
# Out:
# ********************************************************************************
# * Creating file to run benchmark
# ********************************************************************************
# ^C
# ********************************************************************************
# * Completed
# ********************************************************************************

# %% [markdown]
# ## Structures

# %% [markdown]
# ```c
# struct tcphdr {
#     u_short th_sport = 0x9d27
#     u_short th_dport = 0x1896
#     tcp_seq th_seq = 0x6e0e1290
#     tcp_seq th_ack = 0xa79a5193
#     unsigned char th_x2 :4 = 0
#     unsigned char th_off :4 = 0xa
#     u_char th_flags = 0x12
#     u_short th_win = 0xffff
#     u_short th_sum = 0
#     u_short th_urp = 0
# }
#
# struct tcpcb {
#     struct tsegqe_head t_segq = {
#         struct tseg_qent *lh_first = 0
#     }
#     void *[2] t_pspare = [ 0, 0 ]
#     int t_segqlen = 0
#     int t_dupacks = 0
#     struct tcp_timer *t_timers = 0xc3ce0200
#     struct inpcb *t_inpcb = 0xc3cb3af8
#     int t_state = 0x2
#     u_int t_flags = 0x2a0
#     struct vnet *t_vnet = 0
#     tcp_seq snd_una = 0xa79a5192
#     tcp_seq snd_max = 0xa79a5193
#     tcp_seq snd_nxt = 0xa79a5193
#     tcp_seq snd_up = 0xa79a5192
#     tcp_seq snd_wl1 = 0
#     tcp_seq snd_wl2 = 0
#     tcp_seq iss = 0xa79a5192
#     tcp_seq irs = 0
#     tcp_seq rcv_nxt = 0
#     tcp_seq rcv_adv = 0xffff
#     u_long rcv_wnd = 0
#     tcp_seq rcv_up = 0
#     u_long snd_wnd = 0
#     u_long snd_cwnd = 0x3fffc000
#     u_long snd_spare1 = 0
#     u_long snd_ssthresh = 0x3fffc000
#     u_long snd_spare2 = 0
#     tcp_seq snd_recover = 0xa79a5192
#     u_int t_rcvtime = 0x80065647
#     u_int t_starttime = 0
#     u_int t_rtttime = 0x80065647
#     tcp_seq t_rtseq = 0xa79a5192
#     u_int t_bw_spare1 = 0
#     tcp_seq t_bw_spare2 = 0
#     int t_rxtcur = 0x12c
#     u_int t_maxseg = 0x218
#     u_int t_pmtud_saved_maxseg = 0
#     int t_srtt = 0
#     int t_rttvar = 0x4b0
#     int t_rxtshift = 0
#     u_int t_rttmin = 0x3
#     u_int t_rttbest = 0
#     u_long t_rttupdated = 0
#     u_long max_sndwnd = 0
#     int t_softerror = 0
#     char t_oobflags = '\0'
#     char t_iobc = '\0'
#     u_char snd_scale = 0
#     u_char rcv_scale = 0
#     u_char request_r_scale = 0xa
#     u_int32_t ts_recent = 0
#     u_int ts_recent_age = 0
#     u_int32_t ts_offset = 0
#     tcp_seq last_ack_sent = 0
#     u_long snd_cwnd_prev = 0
#     u_long snd_ssthresh_prev = 0
#     tcp_seq snd_recover_prev = 0
#     int t_sndzerowin = 0
#     u_int t_badrxtwin = 0
#     u_char snd_limited = 0
#     int snd_numholes = 0
#     tcp_seq snd_fack = 0
#     int rcv_numsacks = 0
#
# }
# ```

# %%
from IPython.display import display
setup_dependencies()
display(graph_tcp(10))
display(graph_tcp(40))
# Out:
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed

# %%
from IPython.display import display
setup_dependencies()
for i in range(0,40,5):
    display(graph_tcp(i))
# Out:
# Running ipc benchmark
# {u'timestamp': 1485565139240639159L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565139310798993L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 18940}
# {u'timestamp': 1485565139396585326L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 18940}
# {u'timestamp': 1485565139500694326L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 18940, u'local_port': 10141}
# {u'timestamp': 1485565139602961618L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 18940, u'local_port': 10141}
# {u'timestamp': 1485565142370637576L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 18940}
# {u'timestamp': 1485565142494589784L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-close-wait', u'foreign_port': 18940, u'local_port': 10141}
# {u'timestamp': 1485565142597071909L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-fin-wait-2', u'foreign_port': 10141, u'local_port': 18940}
# {u'timestamp': 1485565142700689826L, u'previous_tcp_state': u'state-close-wait', u'tcp_state': u'state-last-ack', u'foreign_port': 18940, u'local_port': 10141}
# {u'timestamp': 1485565142820786993L, u'previous_tcp_state': u'state-fin-wait-2', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 18940}
# Completed
# Running ipc benchmark
# {u'timestamp': 1485565145100635659L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565145176088493L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 36651}
# {u'timestamp': 1485565145261281701L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 36651}
# {u'timestamp': 1485565145365213451L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 36651, u'local_port': 10141}
# {u'timestamp': 1485565145467704284L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 36651, u'local_port': 10141}
# {u'timestamp': 1485565148240631576L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 36651}
# {u'timestamp': 1485565148363807201L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-close-wait', u'foreign_port': 36651, u'local_port': 10141}
# {u'timestamp': 1485565148466011993L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-fin-wait-2', u'foreign_port': 10141, u'local_port': 36651}
# {u'timestamp': 1485565148568085534L, u'previous_tcp_state': u'state-close-wait', u'tcp_state': u'state-last-ack', u'foreign_port': 36651, u'local_port': 10141}
# {u'timestamp': 1485565148689062659L, u'previous_tcp_state': u'state-fin-wait-2', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 36651}
# Completed
# Running ipc benchmark
# {u'timestamp': 1485565150490633284L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565150567458701L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 28464}
# {u'timestamp': 1485565150691230534L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 28464}
# {u'timestamp': 1485565150811237118L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 28464, u'local_port': 10141}
# {u'timestamp': 1485565150929965701L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 28464, u'local_port': 10141}
# {u'timestamp': 1485565156941228534L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 28464}
# {u'timestamp': 1485565157060724659L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 28464, u'local_port': 10141}
# {u'timestamp': 1485565157179905743L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 28464, u'local_port': 10141}
# {u'timestamp': 1485565157300624076L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 10141, u'local_port': 28464}
# {u'timestamp': 1485565157419101618L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 28464}
# Completed
# Running ipc benchmark
# {u'timestamp': 1485565159250638576L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565159320703868L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 25396}
# {u'timestamp': 1485565159441229034L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 25396}
# {u'timestamp': 1485565159561235159L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 25396, u'local_port': 10141}
# {u'timestamp': 1485565159680444451L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 25396, u'local_port': 10141}
# {u'timestamp': 1485565165231228368L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 25396}
# {u'timestamp': 1485565165350707701L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 25396, u'local_port': 10141}
# {u'timestamp': 1485565165469706951L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 25396, u'local_port': 10141}
# {u'timestamp': 1485565165590687284L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 10141, u'local_port': 25396}
# {u'timestamp': 1485565165709697993L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 25396}
# {u'timestamp': 1485565165841239659L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 25396, u'local_port': 10141}
# Completed
# Running ipc benchmark
# {u'timestamp': 1485565167790636826L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565167862005451L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 21300}
# {u'timestamp': 1485565168031227659L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 21300}
# {u'timestamp': 1485565168161237409L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 21300, u'local_port': 10141}
# {u'timestamp': 1485565168279804909L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 21300, u'local_port': 10141}
# {u'timestamp': 1485565177231227576L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 21300}
# {u'timestamp': 1485565177350697701L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 21300, u'local_port': 10141}
# {u'timestamp': 1485565177481238326L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 21300, u'local_port': 10141}
# {u'timestamp': 1485565177611228326L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 10141, u'local_port': 21300}
# {u'timestamp': 1485565177729480909L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 21300}
# Completed
# Running ipc benchmark
# {u'timestamp': 1485565179430637701L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565179500791701L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 21974}
# {u'timestamp': 1485565179661227493L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 21974}
# {u'timestamp': 1485565179791227451L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 21974, u'local_port': 10141}
# {u'timestamp': 1485565179909804951L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 21974, u'local_port': 10141}
# {u'timestamp': 1485565188761227118L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 21974}
# {u'timestamp': 1485565188880695159L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 21974, u'local_port': 10141}
# {u'timestamp': 1485565189011240618L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 21974, u'local_port': 10141}
# {u'timestamp': 1485565189141227493L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 10141, u'local_port': 21974}
# {u'timestamp': 1485565189260302034L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 21974}
# {u'timestamp': 1485565189401227493L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 21974, u'local_port': 10141}
# Completed
# Running ipc benchmark
# {u'timestamp': 1485565191120635909L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565191190636201L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 36633}
# {u'timestamp': 1485565191391230201L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 36633}
# {u'timestamp': 1485565191531227409L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 36633, u'local_port': 10141}
# {u'timestamp': 1485565191649846909L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 36633, u'local_port': 10141}
# {u'timestamp': 1485565225201226201L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 36633}
# {u'timestamp': 1485565225320712284L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 36633, u'local_port': 10141}
# {u'timestamp': 1485565225461226784L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 36633, u'local_port': 10141}
# {u'timestamp': 1485565225601226909L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 10141, u'local_port': 36633}
# {u'timestamp': 1485565225720350909L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 10141, u'local_port': 36633}
# {u'timestamp': 1485565225871226826L, u'previous_tcp_state': u'state-closing', u'tcp_state': u'state-time-wait', u'foreign_port': 36633, u'local_port': 10141}
# Completed
# Running ipc benchmark
# ^C
# {u'timestamp': 1485565228050630243L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-listen', u'foreign_port': 0, u'local_port': 10141}
# {u'timestamp': 1485565228125880368L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-sent', u'foreign_port': 10141, u'local_port': 61743}
# {u'timestamp': 1485565228331226034L, u'previous_tcp_state': u'state-syn-sent', u'tcp_state': u'state-established', u'foreign_port': 10141, u'local_port': 61743}
# {u'timestamp': 1485565228471226909L, u'previous_tcp_state': u'state-closed', u'tcp_state': u'state-syn-received', u'foreign_port': 61743, u'local_port': 10141}
# {u'timestamp': 1485565228590267909L, u'previous_tcp_state': u'state-syn-received', u'tcp_state': u'state-established', u'foreign_port': 61743, u'local_port': 10141}
# {u'timestamp': 1485565233750634701L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 10141, u'local_port': 61743}
# {u'timestamp': 1485565233930633076L, u'previous_tcp_state': u'state-established', u'tcp_state': u'state-fin-wait-1', u'foreign_port': 61743, u'local_port': 10141}
# {u'timestamp': 1485565234111226701L, u'previous_tcp_state': u'state-fin-wait-1', u'tcp_state': u'state-closing', u'foreign_port': 61743, u'local_port': 10141}
# Completed

# %%
setup_dependencies()
display(graph_tcp(40))
# Out:
# Running ipc benchmark
# Completed

# %%
benchmark_tcp_bandwith(latencies=range(0,41,5), output_name="latencies.json")
# Out:
# Latency: 0
# Latency: 5
# Latency: 10
# Latency: 15
# Latency: 20
# Latency: 25
# Latency: 30
# Latency: 35
# Latency: 40
# values collected: 90
# {'latencies': [0, 5, 10, 15, 20, 25, 30, 35, 40],
#  'output': ['613274151',
#   '612790839',
#   '612343352',
#   '616925734',
#   '613003945',
#   '615903857',
#   '614485600',
#   '616299203',
#   '612158384',
#   '620121499',
#   '618677668',
#   '617607852',
#   '614667357',
#   '619638313',
#   '615726593',
#   '615858602',
#   '616059047',
#   '617539746',
#   '614914745',
#   '619168918',
#   '3519364222',
#   '3259375773',
#   '3219419942',
#   '3319437049',
#   '3179472371',
#   '3279346399',
#   '3139479380',
#   '3139412354',
#   '3139430533',
#   '3099433698',
#   '3199410847',
#   '3199504798',
#   '3059443684',
#   '3159400760',
#   '3159346541',
#   '3019343677',
#   '3019656147',
#   '2979423141',
#   '2979399527',
#   '2939436190',
#   '5879285074',
#   '5799378307',
#   '5799406848',
#   '5799400617',
#   '5899166948',
#   '5719182078',
#   '5819413536',
#   '5819258648',
#   '5637403895',
#   '5639402554',
#   '5739294008',
#   '5639392924',
#   '5559378101',
#   '5559391743',
#   '5659408255',
#   '5659408216',
#   '5479300315',
#   '5819382800',
#   '5879196879',
#   '5979375769',
#   '31259298003',
#   '31259320356',
#   '31259319525',
#   '31259327112',
#   '31259328290',
#   '31259243120',
#   '31259323629',
#   '31259266651',
#   '31259285078',
#   '31259212119',
#   '31259259916',
#   '31269310766',
#   '31259340631',
#   '31259286104',
#   '31257250555',
#   '31279336632',
#   '31259230195',
#   '31259293395',
#   '31259253438',
#   '31259321484',
#   '41679269839',
#   '41679281261',
#   '41679245207',
#   '41679305547',
#   '41679254626',
#   '41679247266',
#   '41679289575',
#   '41679258620',
#   '41679286409',
#   '41679218045'],
#  'program_outputs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']}

# %%
benchmark_tcp_bandwith(latencies=range(0,41,5), flags= "-s",trials=3, output_name="latencies_s_3.json")
# Out:
# Latency: 0
# Latency: 5
# Latency: 10
# Latency: 15
# Latency: 20
# Latency: 25
# Latency: 30
# Latency: 35
# Latency: 40
# values collected: 27
# {'latencies': [0, 5, 10, 15, 20, 25, 30, 35, 40],
#  'output': ['617305691',
#   '617049314',
#   '612389661',
#   '620025056',
#   '624002257',
#   '617085439',
#   '5339516165',
#   '5339384835',
#   '5339484893',
#   '5339404502',
#   '5339384621',
#   '5348994408',
#   '10679250022',
#   '10679326041',
#   '10679330904',
#   '10679319254',
#   '10679240629',
#   '10679074907',
#   '16119212844',
#   '16119335088',
#   '16119336832',
#   '16119263478',
#   '16119216078',
#   '16118044317',
#   '21459246990',
#   '21459283888',
#   '21459377680'],
#  'program_outputs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']}

# %%
ax = plot_tcp_bandwidth(input_data_file="latencies.json",y_label="Bandwith (KB/s)",x_label="Latency",label="tcp")
plot_tcp_bandwidth(input_data_file="latencies_s_3.json",trials=3,label="tcp -s", title="TCP bandwidth vs Latency", axis = ax, save_name="tcp_bandwidth.png")
# Out:
# xvs len: 9 yvs len: 90 trials: 10
# xvs len: 9 yvs len: 27 trials: 3

# %%
setup_dependencies()
benchmark_variables(latency=0,output_name="all_variables.json")
# Out:
# Latency: 0
# values collected: 140400
# {'latencies': [0],
#  'output': ['source:10141',
#   'dest:60894',
#   'Seq:2419775086',
#   'Ack:4064340249',
#   'Time:1485563238141668953',
#   'wnd:0',
#   'cwnd:1073725440',
#   'ssthresh:1073725440',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419775087',
#   'Time:1485563238151661369',
#   'wnd:0',
#   'cwnd:1073725440',
#   'ssthresh:1073725440',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419775087',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65535',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419776535',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419777983',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14481',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419777983',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419779431',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419780879',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419782327',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419783775',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419785223',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419786671',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419788119',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419789567',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419791015',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419792463',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419780879',
#   'Time:1485563238151661369',
#   'wnd:63488',
#   'cwnd:17377',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419783775',
#   'Time:1485563238151661369',
#   'wnd:60416',
#   'cwnd:20273',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419786671',
#   'Time:1485563238151661369',
#   'wnd:58368',
#   'cwnd:23169',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419789567',
#   'Time:1485563238151661369',
#   'wnd:55296',
#   'cwnd:26065',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419792463',
#   'Time:1485563238151661369',
#   'wnd:52224',
#   'cwnd:28961',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419793911',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419795359',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419796807',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419798255',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419799703',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419801151',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419802599',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419804047',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419805495',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419806943',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419795359',
#   'Time:1485563238151661369',
#   'wnd:49152',
#   'cwnd:31857',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419798255',
#   'Time:1485563238151661369',
#   'wnd:46080',
#   'cwnd:34753',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419801151',
#   'Time:1485563238151661369',
#   'wnd:43008',
#   'cwnd:37649',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419804047',
#   'Time:1485563238151661369',
#   'wnd:40960',
#   'cwnd:40545',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419806943',
#   'Time:1485563238151661369',
#   'wnd:37888',
#   'cwnd:43441',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419808391',
#   'Time:1485563238151661369',
#   'wnd:34816',
#   'cwnd:43441',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419808391',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419808667',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419810115',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:43441',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419810115',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419811563',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419813011',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419814459',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419815907',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419817355',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419818803',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419820251',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419821699',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419823147',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419824595',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419826043',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419827491',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419828939',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419830387',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419831835',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419833283',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419834731',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419836179',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419837627',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419839075',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419840523',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419841971',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419843419',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419844867',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419846315',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419847763',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419813011',
#   'Time:1485563238151661369',
#   'wnd:63488',
#   'cwnd:45165',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419815907',
#   'Time:1485563238151661369',
#   'wnd:60416',
#   'cwnd:48061',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419818803',
#   'Time:1485563238151661369',
#   'wnd:58368',
#   'cwnd:50957',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419821699',
#   'Time:1485563238151661369',
#   'wnd:55296',
#   'cwnd:53853',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419824595',
#   'Time:1485563238151661369',
#   'wnd:52224',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419827491',
#   'Time:1485563238151661369',
#   'wnd:49152',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419830387',
#   'Time:1485563238151661369',
#   'wnd:46080',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419833283',
#   'Time:1485563238151661369',
#   'wnd:43008',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419836179',
#   'Time:1485563238151661369',
#   'wnd:40960',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419839075',
#   'Time:1485563238151661369',
#   'wnd:37888',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419841971',
#   'Time:1485563238151661369',
#   'wnd:34816',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419844867',
#   'Time:1485563238151661369',
#   'wnd:31744',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419847763',
#   'Time:1485563238151661369',
#   'wnd:28672',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419849211',
#   'Time:1485563238151661369',
#   'wnd:25600',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419849211',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419850163',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419851611',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:56749',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419851611',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419853059',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419854507',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419855955',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419857403',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419858851',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419860299',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419861747',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419863195',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419864643',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419866091',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419867539',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419868987',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419870435',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419871883',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419873331',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419874779',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419876227',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419877675',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419879123',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419880571',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419882019',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419883467',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419884915',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419886363',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419887811',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419889259',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419890707',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419892155',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419893603',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419895051',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:10141',
#   'dest:60894',
#   'Seq:2419896499',
#   'Ack:4064340249',
#   'Time:1485563238151661369',
#   'wnd:65536',
#   'cwnd:14480',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419854507',
#   'Time:1485563238151661369',
#   'wnd:63488',
#   'cwnd:59149',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419857403',
#   'Time:1485563238151661369',
#   'wnd:60416',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419860299',
#   'Time:1485563238151661369',
#   'wnd:58368',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419863195',
#   'Time:1485563238151661369',
#   'wnd:55296',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419866091',
#   'Time:1485563238151661369',
#   'wnd:52224',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419868987',
#   'Time:1485563238151661369',
#   'wnd:49152',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419871883',
#   'Time:1485563238151661369',
#   'wnd:46080',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419874779',
#   'Time:1485563238151661369',
#   'wnd:43008',
#   'cwnd:62045',
#   'ssthresh:269625',
#   'source:60894',
#   'dest:10141',
#   'Seq:4064340249',
#   'Ack:2419877675',
#   'Time:1485563238151661369',
#   'wnd:40960',
#   'cwnd:62045',
#   'ssthresh:269625',
#   ...],
#  'program_outputs': ['']}

# %%
setup_dependencies()
plot_tcp_bandwith_with_time("all_variables.json")
# Out:
# xvs len: 59 yvs len: 59 trials: 1
