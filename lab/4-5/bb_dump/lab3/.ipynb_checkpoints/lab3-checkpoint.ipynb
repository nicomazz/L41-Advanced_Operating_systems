# %% [markdown]
# # Dependencies and initial setup

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline


# all the functions are in lib/
from lib.test import *
from lib.tcp import *

def setup_dependencies():
    # This callback is needed to execute commands from the outside file in lib/
    def exec_cmd(cmd):
        out = !{cmd}
        return out

    set_exec_callback(exec_cmd)
    set_tcp_exec_callback(exec_cmd)
    setup_kernel()
    
setup_dependencies()
setup_pipes()
# !sysctl kern.ipc.maxsockbuf=33554432
#test
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sysctl: cannot stat /proc/sys/kern/ipc/maxsockbuf: No such file or directory

# %%
import os
import sys
sys.version
# Out:
# '2.7.17 (default, Apr  8 2020, 16:59:37) \n[GCC 9.3.0]'

# %%
# !pwd
# Out:
# /data/lab3

# %%
# !ls
# Out:
# .ipynb_checkpoints  lab3.ipynb          lib
# ipc                 lab4_template.ipynb

# %% [markdown]
# # Example commands

# %%
latency = 10

# !ipfw pipe config 1 delay {str(latency)}
# !ipfw pipe config 2 delay {str(latency)}

# %%
print_header("Creating file to run benchmark")

# !ipc/ipc-static -v -i tcp 2thread
    
print_footer("Completed")
# Out:
# ********************************************************************************
# * Creating file to run benchmark
# ********************************************************************************
# ^C
# ********************************************************************************
# * Completed
# ********************************************************************************

# %% [markdown]
# ## Structures

# %% [markdown]
# ```c
# struct tcphdr {
#     u_short th_sport = 0x9d27
#     u_short th_dport = 0x1896
#     tcp_seq th_seq = 0x6e0e1290
#     tcp_seq th_ack = 0xa79a5193
#     unsigned char th_x2 :4 = 0
#     unsigned char th_off :4 = 0xa
#     u_char th_flags = 0x12
#     u_short th_win = 0xffff
#     u_short th_sum = 0
#     u_short th_urp = 0
# }
#
# struct tcpcb {
#     struct tsegqe_head t_segq = {
#         struct tseg_qent *lh_first = 0
#     }
#     void *[2] t_pspare = [ 0, 0 ]
#     int t_segqlen = 0
#     int t_dupacks = 0
#     struct tcp_timer *t_timers = 0xc3ce0200
#     struct inpcb *t_inpcb = 0xc3cb3af8
#     int t_state = 0x2
#     u_int t_flags = 0x2a0
#     struct vnet *t_vnet = 0
#     tcp_seq snd_una = 0xa79a5192
#     tcp_seq snd_max = 0xa79a5193
#     tcp_seq snd_nxt = 0xa79a5193
#     tcp_seq snd_up = 0xa79a5192
#     tcp_seq snd_wl1 = 0
#     tcp_seq snd_wl2 = 0
#     tcp_seq iss = 0xa79a5192
#     tcp_seq irs = 0
#     tcp_seq rcv_nxt = 0
#     tcp_seq rcv_adv = 0xffff
#     u_long rcv_wnd = 0
#     tcp_seq rcv_up = 0
#     u_long snd_wnd = 0
#     u_long snd_cwnd = 0x3fffc000
#     u_long snd_spare1 = 0
#     u_long snd_ssthresh = 0x3fffc000
#     u_long snd_spare2 = 0
#     tcp_seq snd_recover = 0xa79a5192
#     u_int t_rcvtime = 0x80065647
#     u_int t_starttime = 0
#     u_int t_rtttime = 0x80065647
#     tcp_seq t_rtseq = 0xa79a5192
#     u_int t_bw_spare1 = 0
#     tcp_seq t_bw_spare2 = 0
#     int t_rxtcur = 0x12c
#     u_int t_maxseg = 0x218
#     u_int t_pmtud_saved_maxseg = 0
#     int t_srtt = 0
#     int t_rttvar = 0x4b0
#     int t_rxtshift = 0
#     u_int t_rttmin = 0x3
#     u_int t_rttbest = 0
#     u_long t_rttupdated = 0
#     u_long max_sndwnd = 0
#     int t_softerror = 0
#     char t_oobflags = '\0'
#     char t_iobc = '\0'
#     u_char snd_scale = 0
#     u_char rcv_scale = 0
#     u_char request_r_scale = 0xa
#     u_int32_t ts_recent = 0
#     u_int ts_recent_age = 0
#     u_int32_t ts_offset = 0
#     tcp_seq last_ack_sent = 0
#     u_long snd_cwnd_prev = 0
#     u_long snd_ssthresh_prev = 0
#     tcp_seq snd_recover_prev = 0
#     int t_sndzerowin = 0
#     u_int t_badrxtwin = 0
#     u_char snd_limited = 0
#     int snd_numholes = 0
#     tcp_seq snd_fack = 0
#     int rcv_numsacks = 0
#
# }
# ```

# %%
from IPython.display import display
setup_dependencies()
display(graph_tcp(10))
display(graph_tcp(40))
# Out:
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed

# %%
from IPython.display import display
setup_dependencies()
for i in range(0,41,5):
    display(graph_tcp(i))
# Out:
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed
# Running ipc benchmark
# Completed

# %%
setup_dependencies()
display(graph_tcp(40))
# Out:
# Running ipc benchmark
# Completed

# %%
benchmark_tcp_bandwith(latencies=range(0,41,5), trials= 10, output_name="latencies.json")
# Out:
# Latency: 0
# Latency: 5
# Latency: 10
# Latency: 15
# Latency: 20
# Latency: 25
# Latency: 30
# Latency: 35
# Latency: 40
# values collected: 90
# {'latencies': [0, 5, 10, 15, 20, 25, 30, 35, 40],
#  'output': ['625284782',
#   '711630068',
#   '616284068',
#   '708806887',
#   '628682544',
#   '614215587',
#   '618293932',
#   '620681917',
#   '617764533',
#   '617009439',
#   '702156262',
#   '616898966',
#   '616141465',
#   '615782372',
#   '615275557',
#   '616973904',
#   '618796072',
#   '616312152',
#   '708060105',
#   '709587804',
#   '3519425493',
#   '3519237859',
#   '3519416508',
#   '3519434785',
#   '3519418278',
#   '3519412789',
#   '3418946239',
#   '3460355938',
#   '3519406285',
#   '3519446378',
#   '3519449878',
#   '3519399136',
#   '3519411378',
#   '3519448028',
#   '3519417515',
#   '3519401951',
#   '3519430751',
#   '3519404285',
#   '3519408091',
#   '3519405495',
#   '6936509850',
#   '6939390553',
#   '6939407509',
#   '6939388914',
#   '6939197853',
#   '6939468554',
#   '6939347249',
#   '6939356713',
#   '6939394799',
#   '6939329820',
#   '6939384788',
#   '6939369562',
#   '6939384011',
#   '6939310564',
#   '6939450916',
#   '6939449744',
#   '6939424365',
#   '6939424662',
#   '6939390537',
#   '6939366214',
#   '31259366988',
#   '31259331787',
#   '31259254726',
#   '31259324016',
#   '31259291540',
#   '31259291715',
#   '31259346410',
#   '31259343145',
#   '31259394606',
#   '31259306061',
#   '31259307144',
#   '31259269746',
#   '31259341918',
#   '31259323415',
#   '31259306748',
#   '31259323804',
#   '31259341624',
#   '31259338755',
#   '31259325953',
#   '31259307315',
#   '41679136925',
#   '41679219431',
#   '41679383949',
#   '41679386239',
#   '41679218687',
#   '41679360528',
#   '41679372056',
#   '41679255792',
#   '41679277477',
#   '41678837933'],
#  'program_outputs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']}

# %%
benchmark_tcp_bandwith(latencies=range(0,41,5), flags= "-s",trials=10, output_name="latencies_s.json")
# Out:
# Latency: 0
# Latency: 5
# Latency: 10
# Latency: 15
# Latency: 20
# Latency: 25
# Latency: 30
# Latency: 35
# Latency: 40
# values collected: 90
# {'latencies': [0, 5, 10, 15, 20, 25, 30, 35, 40],
#  'output': ['704202068',
#   '695987306',
#   '695426544',
#   '697006988',
#   '699486381',
#   '690085045',
#   '694042829',
#   '702035810',
#   '700390866',
#   '699329412',
#   '694932596',
#   '699189349',
#   '689592922',
#   '700474325',
#   '698821151',
#   '691714109',
#   '691169787',
#   '701263657',
#   '707832898',
#   '694021471',
#   '3189297533',
#   '3189432333',
#   '3189446873',
#   '3189437137',
#   '3189433380',
#   '3189401741',
#   '3189124437',
#   '3189444045',
#   '3189394082',
#   '3189441015',
#   '3189443520',
#   '3189447778',
#   '3189445706',
#   '3189448856',
#   '3189429213',
#   '3189399557',
#   '3189452383',
#   '3188036164',
#   '3189451771',
#   '3189429539',
#   '6169412679',
#   '6169379128',
#   '6169410882',
#   '6169388184',
#   '6169416496',
#   '6169341609',
#   '6169391686',
#   '6169366216',
#   '6169421145',
#   '6169410505',
#   '6169212872',
#   '6169414558',
#   '6169384691',
#   '6169355290',
#   '6169439483',
#   '6169406547',
#   '6169428962',
#   '6169460463',
#   '6169300155',
#   '6169461624',
#   '7749408978',
#   '7949412157',
#   '7629470440',
#   '7509375171',
#   '7389408246',
#   '7269301999',
#   '7149386570',
#   '6909415153',
#   '6889334614',
#   '6669433108',
#   '7749376043',
#   '7949377130',
#   '7629436460',
#   '7509331428',
#   '7389408317',
#   '7269327831',
#   '7149357736',
#   '6909390309',
#   '6890401677',
#   '6669405943',
#   '10329377025',
#   '10529297575',
#   '10169401536',
#   '10009499558',
#   '9849392229',
#   '9689371565',
#   '9529385954',
#   '9209533938',
#   '9149323618',
#   '8889421686'],
#  'program_outputs': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']}

# %%
ax = plot_tcp_bandwidth(input_data_file="latencies.json",trials=10,y_label="Bandwith (KB/s)",x_label="Latency (ms)",label="Auto buffer")
plot_tcp_bandwidth(input_data_file="latencies_s.json",trials=10,label="Fixed size buffer", title="TCP bandwidth vs Latency", axis = ax, save_name="tcp_bandwidth.png")
# Out:
# Now plotting. xvs len: 9 yvs len: 90 trials: 10
# Now plotting. xvs len: 9 yvs len: 90 trials: 10

# %%
att_latency = 10 # 0,5,10,20,40 avilable
JSON_ALL_VARIABLES = latency_name(att_latency)
JSON_ALL_VARIABLES_S = latency_name_s(att_latency)

# %%
benchmark_variables(latency=att_latency,flags="-s",output_name=JSON_ALL_VARIABLES_S)
# Out:
# Latency: 5
# values collected: 140448
# {'latencies': [5],
#  'output': ['snd_cwnd:1073725440',
#   'th_seq:3500972847',
#   'snd_wnd:0',
#   'th_dport:58093',
#   'timestamp:1217627846',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:1073725440',
#   'th_seq:2846000546',
#   'snd_wnd:0',
#   'th_dport:10141',
#   'timestamp:1217785481',
#   'th_sport:58093',
#   'th_ack:3500972848',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500972848',
#   'snd_wnd:65535',
#   'th_dport:58093',
#   'timestamp:1217884782',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14481',
#   'th_seq:2846000546',
#   'snd_wnd:65536',
#   'th_dport:10141',
#   'timestamp:1218005180',
#   'th_sport:58093',
#   'th_ack:3500974296',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500974296',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218084501',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500975744',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218111847',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500977192',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218142795',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500978640',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218157320',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500980088',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218180742',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500981536',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218194411',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500982984',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218217867',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500984432',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218230495',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500985880',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218253526',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500987328',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218266215',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:15929',
#   'th_seq:2846000546',
#   'snd_wnd:1048576',
#   'th_dport:10141',
#   'timestamp:1218290708',
#   'th_sport:58093',
#   'th_ack:3500977192',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:18825',
#   'th_seq:2846000546',
#   'snd_wnd:1045504',
#   'th_dport:10141',
#   'timestamp:1218350670',
#   'th_sport:58093',
#   'th_ack:3500980088',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:21721',
#   'th_seq:2846000546',
#   'snd_wnd:1042432',
#   'th_dport:10141',
#   'timestamp:1218406776',
#   'th_sport:58093',
#   'th_ack:3500982984',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:24617',
#   'th_seq:2846000546',
#   'snd_wnd:1039360',
#   'th_dport:10141',
#   'timestamp:1218463700',
#   'th_sport:58093',
#   'th_ack:3500985880',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:27513',
#   'th_seq:2846000546',
#   'snd_wnd:1036288',
#   'th_dport:10141',
#   'timestamp:1218519690',
#   'th_sport:58093',
#   'th_ack:3500988776',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500988776',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218574718',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500990224',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218588604',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500991672',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218612563',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500993120',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218625663',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500994568',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218648633',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500996016',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218661297',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500997464',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218684279',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3500998912',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218696620',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501000360',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218719065',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501001808',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218731865',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501003256',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218754912',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501004704',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218767727',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501006152',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218790081',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501007600',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218802733',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501009048',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218825537',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501010496',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218838238',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501011944',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218861626',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501013392',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218874396',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501014840',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218897821',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501016288',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1218910553',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:30409',
#   'th_seq:2846000546',
#   'snd_wnd:1033216',
#   'th_dport:10141',
#   'timestamp:1218934624',
#   'th_sport:58093',
#   'th_ack:3500991672',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:33305',
#   'th_seq:2846000546',
#   'snd_wnd:1031168',
#   'th_dport:10141',
#   'timestamp:1218988191',
#   'th_sport:58093',
#   'th_ack:3500994568',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:36201',
#   'th_seq:2846000546',
#   'snd_wnd:1028096',
#   'th_dport:10141',
#   'timestamp:1219044770',
#   'th_sport:58093',
#   'th_ack:3500997464',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:39097',
#   'th_seq:2846000546',
#   'snd_wnd:1025024',
#   'th_dport:10141',
#   'timestamp:1219101181',
#   'th_sport:58093',
#   'th_ack:3501000360',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:41993',
#   'th_seq:2846000546',
#   'snd_wnd:1021952',
#   'th_dport:10141',
#   'timestamp:1219156205',
#   'th_sport:58093',
#   'th_ack:3501003256',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:44889',
#   'th_seq:2846000546',
#   'snd_wnd:1018880',
#   'th_dport:10141',
#   'timestamp:1219214581',
#   'th_sport:58093',
#   'th_ack:3501006152',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:47785',
#   'th_seq:2846000546',
#   'snd_wnd:1015808',
#   'th_dport:10141',
#   'timestamp:1219271698',
#   'th_sport:58093',
#   'th_ack:3501009048',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:50681',
#   'th_seq:2846000546',
#   'snd_wnd:1013760',
#   'th_dport:10141',
#   'timestamp:1219328851',
#   'th_sport:58093',
#   'th_ack:3501011944',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:53577',
#   'th_seq:2846000546',
#   'snd_wnd:1010688',
#   'th_dport:10141',
#   'timestamp:1219386101',
#   'th_sport:58093',
#   'th_ack:3501014840',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:56473',
#   'th_seq:2846000546',
#   'snd_wnd:1007616',
#   'th_dport:10141',
#   'timestamp:1219442476',
#   'th_sport:58093',
#   'th_ack:3501017736',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501017736',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219497662',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501019184',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219513996',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501020632',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219538499',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501022080',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219551573',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501023528',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219575220',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501024976',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219587564',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501026424',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219610895',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501027872',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219623570',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501029320',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219646142',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501030768',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219659202',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501032216',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219681654',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501033664',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219694352',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501035112',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219717191',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501036560',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219729651',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501038008',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219752296',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501039456',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219764842',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501040904',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219787912',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501042352',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219800619',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501043800',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219823652',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501045248',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219836116',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501046696',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219859476',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501048144',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219872027',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501049592',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219894964',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501051040',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219907669',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501052488',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219931042',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501053936',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219943325',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501055384',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219966052',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501056832',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1219979384',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501058280',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220002114',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501059728',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220014995',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501061176',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220038461',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501062624',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220051430',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501064072',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220074275',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501065520',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220087253',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501066968',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220109952',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501068416',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220122864',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501069864',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220145919',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501071312',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220158490',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501072760',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220180930',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501074208',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1220193358',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:59369',
#   'th_seq:2846000546',
#   'snd_wnd:1004544',
#   'th_dport:10141',
#   'timestamp:1220217204',
#   'th_sport:58093',
#   'th_ack:3501020632',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:62265',
#   'th_seq:2846000546',
#   'snd_wnd:1001472',
#   'th_dport:10141',
#   'timestamp:1220271558',
#   'th_sport:58093',
#   'th_ack:3501023528',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:65161',
#   'th_seq:2846000546',
#   'snd_wnd:998400',
#   'th_dport:10141',
#   'timestamp:1220324056',
#   'th_sport:58093',
#   'th_ack:3501026424',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:68057',
#   'th_seq:2846000546',
#   'snd_wnd:996352',
#   'th_dport:10141',
#   'timestamp:1220378882',
#   'th_sport:58093',
#   'th_ack:3501029320',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:70953',
#   'th_seq:2846000546',
#   'snd_wnd:993280',
#   'th_dport:10141',
#   'timestamp:1220434342',
#   'th_sport:58093',
#   'th_ack:3501032216',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:73849',
#   'th_seq:2846000546',
#   'snd_wnd:990208',
#   'th_dport:10141',
#   'timestamp:1220491687',
#   'th_sport:58093',
#   'th_ack:3501035112',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:76745',
#   'th_seq:2846000546',
#   'snd_wnd:987136',
#   'th_dport:10141',
#   'timestamp:1220580390',
#   'th_sport:58093',
#   'th_ack:3501038008',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:79641',
#   'th_seq:2846000546',
#   'snd_wnd:984064',
#   'th_dport:10141',
#   'timestamp:1220637980',
#   'th_sport:58093',
#   'th_ack:3501040904',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:82537',
#   'th_seq:2846000546',
#   'snd_wnd:980992',
#   'th_dport:10141',
#   'timestamp:1220696868',
#   'th_sport:58093',
#   'th_ack:3501043800',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:85433',
#   'th_seq:2846000546',
#   'snd_wnd:978944',
#   'th_dport:10141',
#   'timestamp:1220752312',
#   'th_sport:58093',
#   'th_ack:3501046696',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:88329',
#   'th_seq:2846000546',
#   'snd_wnd:975872',
#   'th_dport:10141',
#   'timestamp:1220809087',
#   'th_sport:58093',
#   'th_ack:3501049592',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:91225',
#   'th_seq:2846000546',
#   'snd_wnd:972800',
#   'th_dport:10141',
#   'timestamp:1220865950',
#   'th_sport:58093',
#   'th_ack:3501052488',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:94121',
#   'th_seq:2846000546',
#   'snd_wnd:969728',
#   'th_dport:10141',
#   'timestamp:1220923636',
#   'th_sport:58093',
#   'th_ack:3501055384',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:97017',
#   'th_seq:2846000546',
#   'snd_wnd:966656',
#   'th_dport:10141',
#   'timestamp:1220980058',
#   'th_sport:58093',
#   'th_ack:3501058280',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:99913',
#   'th_seq:2846000546',
#   'snd_wnd:963584',
#   'th_dport:10141',
#   'timestamp:1221036772',
#   'th_sport:58093',
#   'th_ack:3501061176',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:102809',
#   'th_seq:2846000546',
#   'snd_wnd:961536',
#   'th_dport:10141',
#   'timestamp:1221093502',
#   'th_sport:58093',
#   'th_ack:3501064072',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:105705',
#   'th_seq:2846000546',
#   'snd_wnd:958464',
#   'th_dport:10141',
#   'timestamp:1221160261',
#   'th_sport:58093',
#   'th_ack:3501066968',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:108601',
#   'th_seq:2846000546',
#   'snd_wnd:955392',
#   'th_dport:10141',
#   'timestamp:1221218631',
#   'th_sport:58093',
#   'th_ack:3501069864',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:111497',
#   'th_seq:2846000546',
#   'snd_wnd:952320',
#   'th_dport:10141',
#   'timestamp:1221275255',
#   'th_sport:58093',
#   'th_ack:3501072760',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:114393',
#   'th_seq:2846000546',
#   'snd_wnd:949248',
#   'th_dport:10141',
#   'timestamp:1221329639',
#   'th_sport:58093',
#   'th_ack:3501075656',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501075656',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221387158',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501077104',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221404725',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501078552',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221431012',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501080000',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221443866',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501081448',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221467908',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501082896',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221481114',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501084344',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221504754',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501085792',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221517848',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501087240',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221541665',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501088688',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221554510',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501090136',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221578031',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501091584',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221591209',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501093032',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221616186',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501094480',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221629495',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501095928',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221653835',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   'snd_cwnd:14480',
#   'th_seq:3501097376',
#   'snd_wnd:65536',
#   'th_dport:58093',
#   'timestamp:1221666777',
#   'th_sport:10141',
#   'th_ack:2846000546',
#   'snd_ssthresh:1073725440',
#   ...],
#  'program_outputs': ['']}

# %%
latencies_computed = [0,5,10,20,40]

# %%
for lat in latencies_computed:
    benchmark_variables(
        latency=lat,
        output_name=latency_name(lat))
    benchmark_variables(
        latency=lat,
        flags="-s",
        output_name=latency_name_s(lat))
# Out:
# Latency: 0
# values collected: 139944
# Latency: 0
# values collected: 140408
# Latency: 5
# values collected: 139872
# Latency: 5
# values collected: 140424
# Latency: 10
# values collected: 140616
# Latency: 10
# values collected: 142632
# Latency: 20
# values collected: 140576
# Latency: 20
# values collected: 142928
# Latency: 40
# values collected: 142032
# Latency: 40
# values collected: 140992

# %%
setup_dependencies()
benchmark_variables(latency=att_latency,output_name=JSON_ALL_VARIABLES)
benchmark_variables(latency=att_latency,flags="-s",output_name=JSON_ALL_VARIABLES_S)
# Out:
# Latency: 5
# values collected: 140032
# Latency: 5
# values collected: 140440
# ('yvs len: ', 8454, 'timelen: ', 8454)
# max time: 0.288138448
# Data prepared. Now plotting th_seq..
# xvs len: 8454 yvs len: 8454 trials: 1
# ('yvs len: ', 9044, 'timelen: ', 9044)
# max time: 0.324153338
# Data prepared. Now plotting th_seq..
# xvs len: 9044 yvs len: 9044 trials: 1

# %%
setup_dependencies()

plot_variable(JSON_ALL_VARIABLES, 
              "th_seq",
              sender_side = False, 
              save_name="th_seq_receiver_{}.png".format(att_latency))
plot_variable(JSON_ALL_VARIABLES_S, "th_seq", 
              sender_side = False,
              save_name="th_seq_receiver-s_{}.png".format(att_latency))
# Out:
# ('yvs len: ', 11590, 'timelen: ', 11590)
# ('t0:', 0, 't-1:', 3579388209, 'diff:', 3579388209)
# max time: 3.579388209
# Data prepared. Now plotting th_seq..
# xvs len: 11590 yvs len: 11590 trials: 1
# ('yvs len: ', 11591, 'timelen: ', 11591)
# ('t0:', 0, 't-1:', 2809395500, 'diff:', 2809395500)
# max time: 2.8093955
# Data prepared. Now plotting th_seq..
# xvs len: 11591 yvs len: 11591 trials: 1

# %%
#setup_dependencies()
for lat in latencies_computed:
    compare_bandwidth(lat)

#ax.set_yscale(log)
# factor = 20, times = 10, time diff 0.0001
# factor = 20 times =
# Out:
# Now plotting. xvs len: 46 yvs len: 46 trials: 1
# Now plotting. xvs len: 44 yvs len: 44 trials: 1
# Now plotting. xvs len: 46 yvs len: 46 trials: 1
# Now plotting. xvs len: 43 yvs len: 43 trials: 1
# Now plotting. xvs len: 44 yvs len: 44 trials: 1
# Now plotting. xvs len: 67 yvs len: 67 trials: 1
# Now plotting. xvs len: 64 yvs len: 64 trials: 1
# Now plotting. xvs len: 40 yvs len: 40 trials: 1
# Now plotting. xvs len: 133 yvs len: 133 trials: 1
# Now plotting. xvs len: 58 yvs len: 58 trials: 1

# %%
compare_wnd(5)
# Out:
# Now plotting. xvs len: 5893 yvs len: 5893 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1

# %%
compare_cwnd(att_latency)
# Out:
# ('yvs len: ', 5987, 'timelen: ', 5987)
# ('t0:', 0, 't-1:', 3559389375, 'diff:', 3559389375)
# max time: 3.559389375
# Data prepared. Now plotting snd_cwnd..
# xvs len: 5987 yvs len: 5987 trials: 1
# ('yvs len: ', 6238, 'timelen: ', 6238)
# ('t0:', 0, 't-1:', 2789396250, 'diff:', 2789396250)
# max time: 2.78939625
# Data prepared. Now plotting snd_cwnd..
# xvs len: 6238 yvs len: 6238 trials: 1

# %%
plot_tcp_cwnd_wnd_ssthresh(att_latency)
# Out:
# ('yvs len: ', 5987, 'timelen: ', 5987)
# ('t0:', 0, 't-1:', 3559389375, 'diff:', 3559389375)
# max time: 3.559389375
# Data prepared. Now plotting snd_cwnd..
# xvs len: 5987 yvs len: 5987 trials: 1
# ('yvs len: ', 5987, 'timelen: ', 5987)
# ('t0:', 0, 't-1:', 3559389375, 'diff:', 3559389375)
# max time: 3.559389375
# Data prepared. Now plotting snd_wnd..
# xvs len: 5987 yvs len: 5987 trials: 1
# ('yvs len: ', 6238, 'timelen: ', 6238)
# ('t0:', 0, 't-1:', 2789396250, 'diff:', 2789396250)
# max time: 2.78939625
# Data prepared. Now plotting snd_cwnd..
# xvs len: 6238 yvs len: 6238 trials: 1
# ('yvs len: ', 6238, 'timelen: ', 6238)
# ('t0:', 0, 't-1:', 2789396250, 'diff:', 2789396250)
# max time: 2.78939625
# Data prepared. Now plotting snd_wnd..
# xvs len: 6238 yvs len: 6238 trials: 1

# %%
for lat in latencies_computed:
    print "-> Latency {} ms".format(lat)
    compare_all(lat)
# Out:
# -> Latency 0 ms
# Now plotting. xvs len: 46 yvs len: 46 trials: 1
# Now plotting. xvs len: 44 yvs len: 44 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5891 yvs len: 5891 trials: 1
# Now plotting. xvs len: 5891 yvs len: 5891 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5891 yvs len: 5891 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5891 yvs len: 5891 trials: 1
# Now plotting. xvs len: 5891 yvs len: 5891 trials: 1
# -> Latency 5 ms
# Now plotting. xvs len: 46 yvs len: 46 trials: 1
# Now plotting. xvs len: 43 yvs len: 43 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5893 yvs len: 5893 trials: 1
# Now plotting. xvs len: 5893 yvs len: 5893 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5893 yvs len: 5893 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5879 yvs len: 5879 trials: 1
# Now plotting. xvs len: 5893 yvs len: 5893 trials: 1
# Now plotting. xvs len: 5893 yvs len: 5893 trials: 1
# -> Latency 10 ms
# Now plotting. xvs len: 44 yvs len: 44 trials: 1
# Now plotting. xvs len: 67 yvs len: 67 trials: 1
# Now plotting. xvs len: 5987 yvs len: 5987 trials: 1
# Now plotting. xvs len: 6238 yvs len: 6238 trials: 1
# Now plotting. xvs len: 6238 yvs len: 6238 trials: 1
# Now plotting. xvs len: 5987 yvs len: 5987 trials: 1
# Now plotting. xvs len: 5987 yvs len: 5987 trials: 1
# Now plotting. xvs len: 6238 yvs len: 6238 trials: 1
# Now plotting. xvs len: 5987 yvs len: 5987 trials: 1
# Now plotting. xvs len: 5987 yvs len: 5987 trials: 1
# Now plotting. xvs len: 6238 yvs len: 6238 trials: 1
# Now plotting. xvs len: 6238 yvs len: 6238 trials: 1
# -> Latency 20 ms
# Now plotting. xvs len: 64 yvs len: 64 trials: 1
# Now plotting. xvs len: 40 yvs len: 40 trials: 1
# Now plotting. xvs len: 5982 yvs len: 5982 trials: 1
# Now plotting. xvs len: 6275 yvs len: 6275 trials: 1
# Now plotting. xvs len: 6275 yvs len: 6275 trials: 1
# Now plotting. xvs len: 5982 yvs len: 5982 trials: 1
# Now plotting. xvs len: 5982 yvs len: 5982 trials: 1
# Now plotting. xvs len: 6275 yvs len: 6275 trials: 1
# Now plotting. xvs len: 5982 yvs len: 5982 trials: 1
# Now plotting. xvs len: 5982 yvs len: 5982 trials: 1
# Now plotting. xvs len: 6275 yvs len: 6275 trials: 1
# Now plotting. xvs len: 6275 yvs len: 6275 trials: 1
# -> Latency 40 ms
# Now plotting. xvs len: 133 yvs len: 133 trials: 1
# Now plotting. xvs len: 58 yvs len: 58 trials: 1
# Now plotting. xvs len: 6055 yvs len: 6055 trials: 1
# Now plotting. xvs len: 6033 yvs len: 6033 trials: 1
# Now plotting. xvs len: 6033 yvs len: 6033 trials: 1
# Now plotting. xvs len: 6055 yvs len: 6055 trials: 1
# Now plotting. xvs len: 6055 yvs len: 6055 trials: 1
# Now plotting. xvs len: 6033 yvs len: 6033 trials: 1
# Now plotting. xvs len: 6055 yvs len: 6055 trials: 1
# Now plotting. xvs len: 6055 yvs len: 6055 trials: 1
# Now plotting. xvs len: 6033 yvs len: 6033 trials: 1
# Now plotting. xvs len: 6033 yvs len: 6033 trials: 1

# %%
#!ipc/ipc-static -i tcp -B -b 1048576 -q 2thread
# !ipc/ipc-static -i tcp -B -b 1048576 2thread
# Out:
# /usr/bin/sh: ipc/ipc-static: cannot execute binary file: Exec format error
